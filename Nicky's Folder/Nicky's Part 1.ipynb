# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFECV
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVR
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

col_names = ['srcip', 'sport', 'dstip', 'dsport', 'proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'Sload', 'Dload',
             'Spkts', 'Dpkts', 'swin', 'dwin', 'stcpb',  'dtcpb', 'smeanz', 'dmeanz', 'trans_depth', 'res_bdy_len', 'Sjit', 'Djit', 'Stime', 'Ltime',
             'Sintpkt', 'Dintpkt', 'tcprtt', 'synack', 'ackdat', 'is_sm_ips_ports', 'ct_state_ttl', 'ct_flw_http_mthd', 'is_ftp_login',  'ct_ftp_cmd',
             'ct_srv_src', 'ct_srv_dst', 'ct_dst_ltm', 'ct_src_ ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label']
balanced_set = pd.read_csv("../UNSW-NB15-BALANCED-TRAIN.csv", header=None, names=col_names, skiprows=1)
balanced_set.head()
# Out:
#           srcip  sport           dstip dsport proto state       dur  sbytes  \
# 0    59.166.0.1  55490   149.171.126.3     53   udp   CON  0.001050     146
# 1    59.166.0.9  26756   149.171.126.8     21   tcp   FIN  4.264797    2934
# 2  175.45.176.1   1043  149.171.126.14     53   udp   INT  0.000003     114
# 3  175.45.176.3   1043  149.171.126.18     53   udp   INT  0.000003     114
# 4    59.166.0.4  34472   149.171.126.3  10429   tcp   FIN  0.052957    3718
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0     178    31  ...           0           3           4          3
# 1    3738    31  ...           4           5           5         15
# 2       0   254  ...                      17          17         14
# 3       0   254  ...                      25          25         25
# 4   43086    31  ...                       5           8          3
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
feature_cols = ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'Sload', 'Dload', 'Spkts', 'Dpkts', 'swin', 'dwin', 'stcpb',  'dtcpb', 'smeanz', 'dmeanz', 'trans_depth', 'res_bdy_len', 'Sjit', 'Djit', 'Stime', 'Ltime','Sintpkt', 'Dintpkt', 'tcprtt', 'synack', 'ackdat', 'is_sm_ips_ports', 'ct_state_ttl', 'ct_flw_http_mthd', 'is_ftp_login',  'ct_ftp_cmd','ct_srv_src', 'ct_srv_dst', 'ct_dst_ltm', 'ct_src_ ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm']

# %%
balanced_set['proto'] = pd.factorize(balanced_set['proto'])[0]
balanced_set['state'] = pd.factorize(balanced_set['state'])[0]
balanced_set['service'] = pd.factorize(balanced_set['service'])[0]
balanced_set['srcip'] = pd.factorize(balanced_set['srcip'])[0]
balanced_set['sport'] = pd.factorize(balanced_set['sport'])[0]
balanced_set['dstip'] = pd.factorize(balanced_set['dstip'])[0]
balanced_set['dsport'] = pd.factorize(balanced_set['dsport'])[0]
imp = SimpleImputer(missing_values=pd.NA, strategy = 'most_frequent')
balanced_set[['ct_flw_http_mthd']] = imp.fit_transform(balanced_set[['ct_flw_http_mthd']])
balanced_set[['is_ftp_login']] = imp.fit_transform(balanced_set[['is_ftp_login']])
imp2 = SimpleImputer(missing_values=' ', strategy = 'most_frequent')
balanced_set[['ct_ftp_cmd']] = imp2.fit_transform(balanced_set[['ct_ftp_cmd']])
balanced_set.head(250000)
# Out:
#         srcip  sport  dstip  dsport  proto  state       dur  sbytes  dbytes  \
# 0           0      0      0       0      0      0  0.001050     146     178
# 1           1      1      1       1      1      1  4.264797    2934    3738
# 2           2      2      2       0      0      2  0.000003     114       0
# 3           3      2      3       0      0      2  0.000003     114       0
# 4           4      3      0       2      1      1  0.052957    3718   43086
# ...       ...    ...    ...     ...    ...    ...       ...     ...     ...
# 249995     13  36806      4       0      0      0  0.000995     146     178
# 249996     10  32927      1   32808      1      1  0.019048    3182   35916
# 249997      2      2      3       0      0      2  0.000010     114       0
# 249998      4  27342     13   32809      1      1  0.035941    3614   49036
# 249999      8   8371     12       0      0      0  0.001006     146     178
#
# ...

# %%
train_set = balanced_set.copy()[0:200000]
train_set['attack_cat'] = pd.factorize(train_set['attack_cat'])[0]
train_attack_cat = train_set.loc[train_set['Label'] != 0]
y_attack_cat_train = train_attack_cat['attack_cat']
y_label_train = train_set["Label"]
X_train = train_set[feature_cols]
X_train_attack_cat = train_attack_cat[feature_cols]

# %%
estimator = LogisticRegression()
selector = RFECV(estimator, min_features_to_select=10, scoring="accuracy", step=1, n_jobs=-1)
selector_attack_cat = selector.fit(X_train_attack_cat, y_attack_cat_train)
selector_label = selector.fit(X_train, y_label_train)

# %%
cv_results_attack_cat = pd.DataFrame(selector_attack_cat.cv_results_)
plt.figure()
plt.xlabel("# of tested features")
plt.ylabel("Mean Accuracy")
plt.errorbar(
    x=cv_results_attack_cat["n_features"],
    y=cv_results_attack_cat["mean_test_score"],
    yerr=cv_results_attack_cat["std_test_score"],
)
plt.title("Recursive Feature Elimination to select features using attack_cat as y")
plt.show()

# %%
cv_results_label = pd.DataFrame(selector_label.cv_results_)
plt.figure()
plt.xlabel("# of tested features")
plt.ylabel("Mean Accuracy")
plt.errorbar(
    x=cv_results_label["n_features"],
    y=cv_results_label["mean_test_score"],
    yerr=cv_results_label["std_test_score"],
)
plt.title("Recursive Feature Elimination to select features using label as y")
plt.show()

# %%
print("Mean test accuracy of # of features used for attack_cat:")
for i in range(len(cv_results_attack_cat["n_features"])):
    print(f"{cv_results_attack_cat["n_features"][i]} features {cv_results_attack_cat["mean_test_score"][i]}")
# Out:
# Mean test accuracy of # of features used for attack_cat:
# 10 features 0.991015
# 11 features 0.9900800000000001
# 12 features 0.971125
# 13 features 0.9707049999999999
# 14 features 0.949385
# 15 features 0.925705
# 16 features 0.91752
# 17 features 0.9067399999999999
# 18 features 0.907235
# 19 features 0.9076850000000001
# 20 features 0.9074500000000001
# 21 features 0.902065
# 22 features 0.84277
# 23 features 0.8418850000000001
# 24 features 0.841995
# 25 features 0.8456849999999999
# 26 features 0.846805
# 27 features 0.84803
# 28 features 0.85422
# 29 features 0.8554300000000001
# 30 features 0.85545
# 31 features 0.8554400000000001
# 32 features 0.8554400000000001
# 33 features 0.8554400000000001
# 34 features 0.8554400000000001
# 35 features 0.8554400000000001
# 36 features 0.8554400000000001
# 37 features 0.8554400000000001
# 38 features 0.8554400000000001
# 39 features 0.8554400000000001
# 40 features 0.8554400000000001
# 41 features 0.8554400000000001
# ...

# %%
print("Mean test accuracy of # of features used for label:")
for i in range(len(cv_results_label["n_features"])):
    print(f"{cv_results_label["n_features"][i]} features {cv_results_label["mean_test_score"][i]}")
# Out:
# Mean test accuracy of # of features used for label:
# 10 features 0.991015
# 11 features 0.9900800000000001
# 12 features 0.971125
# 13 features 0.9707049999999999
# 14 features 0.949385
# 15 features 0.925705
# 16 features 0.91752
# 17 features 0.9067399999999999
# 18 features 0.907235
# 19 features 0.9076850000000001
# 20 features 0.9074500000000001
# 21 features 0.902065
# 22 features 0.84277
# 23 features 0.8418850000000001
# 24 features 0.841995
# 25 features 0.8456849999999999
# 26 features 0.846805
# 27 features 0.84803
# 28 features 0.85422
# 29 features 0.8554300000000001
# 30 features 0.85545
# 31 features 0.8554400000000001
# 32 features 0.8554400000000001
# 33 features 0.8554400000000001
# 34 features 0.8554400000000001
# 35 features 0.8554400000000001
# 36 features 0.8554400000000001
# 37 features 0.8554400000000001
# 38 features 0.8554400000000001
# 39 features 0.8554400000000001
# 40 features 0.8554400000000001
# 41 features 0.8554400000000001
# ...

# %%
selected_features_attack_cat = []
print(f"Optimal amount of features for attack_cat: {selector_attack_cat.n_features_}")
print("Features selected:")
for i in range(len(selector_attack_cat.ranking_)):
    if (selector_attack_cat.ranking_[i] == 1):
        print(f"{feature_cols[i]}")
        selected_features_attack_cat.append(feature_cols[i])
# Out:
# Optimal amount of features for attack_cat: 10
# Features selected:
# proto
# sttl
# dttl
# Spkts
# swin
# dwin
# ct_srv_src
# ct_srv_dst
# ct_src_dport_ltm
# ct_dst_src_ltm

# %%
selected_features_label = []
print(f"Optimal amount of features for Label: {selector_label.n_features_}")
print("Features selected:")
for i in range(len(selector_label.ranking_)):
    if (selector_label.ranking_[i] == 1):
        print(f"{feature_cols[i]}")
        selected_features_label.append(feature_cols[i])
# Out:
# Optimal amount of features for Label: 10
# Features selected:
# proto
# sttl
# dttl
# Spkts
# swin
# dwin
# ct_srv_src
# ct_srv_dst
# ct_src_dport_ltm
# ct_dst_src_ltm

# %%
validation_cutoff = 300000
validation_set = balanced_set[200000:validation_cutoff]
test_set = balanced_set[validation_cutoff:400000]
validation_set = validation_set.replace({np.nan: "None"})
validation_set = validation_set.replace({"Backdoor": "Backdoors"})
test_set = test_set.replace({np.nan: "None"})
test_set = test_set.replace({"Backdoor": "Backdoors"})
validation_set["attack_cat"] = validation_set["attack_cat"].str.strip()
test_set["attack_cat"] = test_set["attack_cat"].str.strip()

# %%
X_train_label = X_train[selected_features_label]
X_validation_label = validation_set[selected_features_label]
X_test_label = test_set[selected_features_label]
y_attack_cat_validation = validation_set["attack_cat"]
y_label_validation = validation_set["Label"]
y_attack_cat_test = test_set["attack_cat"]
y_label_test = test_set["Label"]

# %%
neigh_label = KNeighborsClassifier(n_neighbors=10)
neigh_label.fit(X_validation_label, y_label_validation)
Label_test_predict = neigh_label.predict(X_test_label)

# %%
print("Classifier: K-Nearest Neighbours Classifier\n")
print(metrics.classification_report(y_label_test, Label_test_predict))
# Out:
# Classifier: K-Nearest Neighbours Classifier
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     49934
#            1       0.99      1.00      0.99     50066
#
#     accuracy                           0.99    100000
#    macro avg       0.99      0.99      0.99    100000
# weighted avg       0.99      0.99      0.99    100000

# %%
X_validation_attack_cat = validation_set[selected_features_attack_cat]
X_test_attack_cat = test_set[selected_features_attack_cat]
X_test_attack_cat = X_test_attack_cat[selected_features_attack_cat]
neigh_attack_cat = KNeighborsClassifier(n_neighbors=10)
neigh_attack_cat.fit(X_validation_attack_cat, y_attack_cat_validation)
attack_cat_test_predict = neigh_attack_cat.predict(X_test_attack_cat)

# %%
print("Classifier: K-Nearest Neighbours Classifier\n")
print(metrics.classification_report(y_attack_cat_test, attack_cat_test_predict, labels=["None", "Generic", "Fuzzers", "Exploits", "DoS", "Reconnaissance", "Analysis", "Shellcode", "Backdoors", "Worms"]))
